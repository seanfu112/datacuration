# %% [markdown]
# ###Imported Necessary APIs and Modules
# - Imported Pandas, MatPlotLib, and BeautifulSoup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from bs4 import BeautifulSoup

# %% [markdown]
# ###Imported List of Countries and its population & percentage & Date Updated using Pandas
# - Set Countries as index
# - Calculate percentage by dividing country population by world population

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
infotable = pd.read_html(url, match = "Country", flavor = 'bs4')
infotable = infotable[0]
df = pd.DataFrame()
df['Country'] = infotable['Country / Dependency']
df['Population'] = infotable['Population']
df['Percentage of World'] = df["Population"]/8063792000
df["Date Updated"] = infotable["Date"]
df = df.drop([0],axis=0)
df = df.set_index("Country")
df
# Out:
#                         Population  Percentage of World Date Updated
# Country
# China                   1411750000             0.175073  31 Dec 2022
# India                   1392329000             0.172664   1 Mar 2023
# United States            335466000             0.041602   5 Oct 2023
# Indonesia                278696200             0.034561   1 Jul 2023
# Pakistan                 241499431             0.029949   1 Mar 2023
# ...                            ...                  ...          ...
# Seychelles                  100447             0.000012  22 Apr 2022
# Tonga                       100179             0.000012   1 Jan 2022
# US Virgin Islands (US)       87146             0.000011   1 Apr 2020
# Isle of Man (UK)             84069             0.000010  30 May 2021
# Andorra                      83523             0.000010  30 Jun 2023
#
# [203 rows x 3 columns]

# %% [markdown]
# ###Use MatPlotLib to Draw a Bar graph for the 30 countries with the largest population.

# %%
temp = df[0:30]
fig = plt.figure(figsize=(20,30))
ax=fig.add_subplot(311)
ax.bar(temp.index, temp["Population"])
ax.set(title="Population of 30 Largest Countries", xlabel='Countries', ylabel='Population')
ax.set_xticklabels(temp.index,rotation=90)
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))
# Out:
# <ipython-input-131-ef26af2c9711>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(temp.index,rotation=90)
# [Text(0, 0, 'China'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'United States'),
#  Text(3, 0, 'Indonesia'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Nigeria'),
#  Text(6, 0, 'Brazil'),
#  Text(7, 0, 'Bangladesh'),
#  Text(8, 0, 'Russia'),
#  Text(9, 0, 'Mexico'),
#  Text(10, 0, 'Japan'),
#  Text(11, 0, 'Philippines'),
#  Text(12, 0, 'Ethiopia'),
#  Text(13, 0, 'Egypt'),
#  Text(14, 0, 'Vietnam'),
#  Text(15, 0, 'DR Congo'),
#  Text(16, 0, 'Iran'),
#  Text(17, 0, 'Turkey'),
#  Text(18, 0, 'Germany'),
#  Text(19, 0, 'Thailand'),
#  Text(20, 0, 'France'),
#  Text(21, 0, 'United Kingdom'),
#  Text(22, 0, 'Tanzania'),
#  Text(23, 0, 'South Africa'),
#  Text(24, 0, 'Italy'),
#  Text(25, 0, 'Myanmar'),
#  Text(26, 0, 'Colombia'),
#  Text(27, 0, 'Kenya'),
#  Text(28, 0, 'South Korea'),
#  Text(29, 0, 'Spain')]

# %% [markdown]
# ###Use MatPlotLib to draw a pie chart and distribution for the top 30 countries with the largest populations.

# %%
plot=temp.plot.pie(y='Population', title = "Percentage of Population for 30 Largest Countries",figsize=(20, 10))

# %% [markdown]
# ### Export Data in the DataFrame to a CSV file

# %%
df.to_csv("Data.csv")

# %% [markdown]
# ###Summary
# - What surprised me the most was the sheer difference in population between the largest countries and the smallest.
# - I think the most important part of my data is the distribution of populations.
# - Drawing a pie chart helped visualize the difference in percentages of a country's population compared to others.
# - Drawing the bar graph was a easy way to visualize the large amounts of countrys' population.
